# %%
#Importing Libraries
import numpy as np
import tensorflow as tf
import pickle
from tensorflow.keras import layers , activations , models , preprocessing

#importing data
# !wget https://github.com/shubham0204/Dataset_Archives/blob/master/chatbot_nlp.zip?raw=true -O chatbot_nlp.zip
# !unzip chatbot_nlp.zip
# Out:
# /kaggle/input/chatterbotenglish/greetings.yml
# /kaggle/input/chatterbotenglish/health.yml
# /kaggle/input/chatterbotenglish/food.yml
# /kaggle/input/chatterbotenglish/computers.yml
# /kaggle/input/chatterbotenglish/movies.yml
# /kaggle/input/chatterbotenglish/ai.yml
# /kaggle/input/chatterbotenglish/emotion.yml
# /kaggle/input/chatterbotenglish/botprofile.yml
# /kaggle/input/chatterbotenglish/gossip.yml
# /kaggle/input/chatterbotenglish/humor.yml
# /kaggle/input/chatterbotenglish/trivia.yml
# /kaggle/input/chatterbotenglish/literature.yml
# /kaggle/input/chatterbotenglish/science.yml
# /kaggle/input/chatterbotenglish/history.yml
# /kaggle/input/chatterbotenglish/sports.yml
# /kaggle/input/chatterbotenglish/money.yml
# /kaggle/input/chatterbotenglish/psychology.yml
# /kaggle/input/chatterbotenglish/politics.yml

# %%
import tensorflow as tf
from tensorflow.keras import layers, preprocessing, utils
import yaml

print( tf.version)
# Out:
# <module 'tensorflow_core._api.v2.version' from '/opt/conda/lib/python3.7/site-packages/tensorflow_core/_api/v2/version/__init__.py'>

# %%
questions=list()
answers=list()

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        file = open(os.path.join(dirname, filename), 'rb')
        docs = yaml.safe_load(file)
        conversations = docs['conversations']
        for con in conversations:
            if len(con)>2:
                questions.append(con[0])
                replies=con[1:]
                ans=""
                for rep in replies:
                    ans+=' '+rep
                answers.append(ans)
            elif len(con)>1:
                questions.append(con[0])
                answers.append(con[1])
                
answers_with_tags=list()
for i in range( len(answers)):
    if type(answers[i])==str:
        answers_with_tags.append(answers[i])
    else:
        questions.pop(i)

answers=list()
for ans in answers_with_tags:
    answers.append('<START> '+ans+' <END>')

tokenizer=preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(questions+answers)
VOCAB_SIZE= len(tokenizer.word_index)+1
print('VOCAB SIZE : {}'.format(VOCAB_SIZE))
# Out:
# VOCAB SIZE : 1894

# %%
from gensim.models import Word2Vec
import re

vocab=[]
for word in tokenizer.word_index:
    vocab.append(word)
    
def tokenize(sentences):
    tokens_list=[]
    vocabulary=[]
    for sentence in sentences:
        sentence = sentence.lower()
        sentence = re.sub( '^a-zA-Z',' ',sentence)
        tokens = sentence.split()
        vocabulary+=tokens
        tokens_list.append(tokens)
    return tokens_list,vocabulary

p=tokenize(questions+answers)
model = Word2Vec(p[0])
'''
embedding_matrix = np.zeros((VOCAB_SIZE,100))
for i in range(len(tokenizer.word_index)):
    embedding_matrix[i] = model[vocab[i]]
   ''' 
tokenized_questions = tokenizer.texts_to_sequences(questions)
maxlen_questions = max([len(x) for x in tokenized_questions])
padded_questions = preprocessing.sequence.pad_sequences(tokenized_questions, maxlen=maxlen_questions, padding='post')
encoder_input_data = np.array( padded_questions )
print(encoder_input_data.shape, maxlen_questions)

tokenized_answers = tokenizer.texts_to_sequences(answers)
maxlen_answers = max([len(x) for x in tokenized_answers])
padded_answers = preprocessing.sequence.pad_sequences(tokenized_answers, maxlen=maxlen_answers, padding='post')
decoder_input_data = np.array(padded_answers)
print(decoder_input_data.shape, maxlen_answers)

tokenized_answers = tokenizer.texts_to_sequences(answers)
for i in range(len(tokenized_answers)):
    tokenized_answers[i]=tokenized_answers[i][1:]
padded_answers = preprocessing.sequence.pad_sequences(tokenized_answers, maxlen=maxlen_answers, padding='post')
one_hot_answers = utils.to_categorical(padded_answers, VOCAB_SIZE)
decoder_output_data = np.array(one_hot_answers)
print(decoder_output_data.shape)
# Out:
# (564, 22) 22
# (564, 74) 74
# (564, 74, 1894)

# %%
encoder_inputs = tf.keras.layers.Input(shape=( None , ))
encoder_embedding = tf.keras.layers.Embedding( VOCAB_SIZE, 200 , mask_zero=True ) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 200 , return_state=True )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( None ,  ))
decoder_embedding = tf.keras.layers.Embedding( VOCAB_SIZE, 200 , mask_zero=True) (decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM( 200 , return_state=True , return_sequences=True )
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( VOCAB_SIZE , activation=tf.keras.activations.softmax ) 
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, None, 200)    378800      input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 200)    378800      input_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 200), (None, 320800      embedding[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, None, 200),  320800      embedding_1[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 1894)   380694      lstm_1[0][0]
# ==================================================================================================
# Total params: 1,779,894
# Trainable params: 1,779,894
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_output_data, batch_size=50, epochs=100 ) 
model.save( 'model.h5' )
# Out:
# Train on 564 samples
# Epoch 1/100
# 564/564 [==============================] - 12s 22ms/sample - loss: 1.4508 - accuracy: 0.1127
# Epoch 2/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.2776 - accuracy: 0.0715
# Epoch 3/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.1326 - accuracy: 0.0705
# Epoch 4/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.1067 - accuracy: 0.0924
# Epoch 5/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.0955 - accuracy: 0.1272
# Epoch 6/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.0863 - accuracy: 0.0966
# Epoch 7/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.0724 - accuracy: 0.1485
# Epoch 8/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.0553 - accuracy: 0.1517
# Epoch 9/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.0380 - accuracy: 0.1518
# Epoch 10/100
# 564/564 [==============================] - 5s 10ms/sample - loss: 1.0242 - accuracy: 0.1531
# Epoch 11/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.0123 - accuracy: 0.1534
# Epoch 12/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 1.0018 - accuracy: 0.1539
# Epoch 13/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9896 - accuracy: 0.1549
# Epoch 14/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9786 - accuracy: 0.1657
# Epoch 15/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9687 - accuracy: 0.1780
# Epoch 16/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9581 - accuracy: 0.1852
# Epoch 17/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9478 - accuracy: 0.1877
# Epoch 18/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9381 - accuracy: 0.1908
# Epoch 19/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9285 - accuracy: 0.1910
# Epoch 20/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9190 - accuracy: 0.1958
# Epoch 21/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.9095 - accuracy: 0.1997
# Epoch 22/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8995 - accuracy: 0.2097
# Epoch 23/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8903 - accuracy: 0.2207
# Epoch 24/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8805 - accuracy: 0.2303
# Epoch 25/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8706 - accuracy: 0.2375
# Epoch 26/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8609 - accuracy: 0.2525
# Epoch 27/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8512 - accuracy: 0.2596
# Epoch 28/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8414 - accuracy: 0.2645
# Epoch 29/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8319 - accuracy: 0.2716
# Epoch 30/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8224 - accuracy: 0.2762
# Epoch 31/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8132 - accuracy: 0.2849
# Epoch 32/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.8036 - accuracy: 0.2881
# Epoch 33/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7948 - accuracy: 0.2925
# Epoch 34/100
# 564/564 [==============================] - 5s 10ms/sample - loss: 0.7859 - accuracy: 0.2977
# Epoch 35/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7772 - accuracy: 0.2995
# Epoch 36/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7690 - accuracy: 0.3020
# Epoch 37/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7605 - accuracy: 0.3051
# Epoch 38/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7523 - accuracy: 0.3087
# Epoch 39/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7441 - accuracy: 0.3124
# Epoch 40/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7358 - accuracy: 0.3139
# Epoch 41/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7272 - accuracy: 0.3200
# Epoch 42/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7192 - accuracy: 0.3246
# Epoch 43/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7115 - accuracy: 0.3292
# Epoch 44/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.7029 - accuracy: 0.3345
# Epoch 45/100
# 564/564 [==============================] - 5s 10ms/sample - loss: 0.6949 - accuracy: 0.3405
# Epoch 46/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6873 - accuracy: 0.3404
# Epoch 47/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6793 - accuracy: 0.3452
# Epoch 48/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6714 - accuracy: 0.3497
# Epoch 49/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6637 - accuracy: 0.3550
# Epoch 50/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6556 - accuracy: 0.3601
# Epoch 51/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6480 - accuracy: 0.3626
# Epoch 52/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6400 - accuracy: 0.3700
# Epoch 53/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6325 - accuracy: 0.3718
# Epoch 54/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6249 - accuracy: 0.3781
# Epoch 55/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6170 - accuracy: 0.3816
# Epoch 56/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6091 - accuracy: 0.3869
# Epoch 57/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.6016 - accuracy: 0.3941
# Epoch 58/100
# 564/564 [==============================] - 5s 10ms/sample - loss: 0.5944 - accuracy: 0.3997
# Epoch 59/100
# 564/564 [==============================] - 6s 10ms/sample - loss: 0.5869 - accuracy: 0.4027
# Epoch 60/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5790 - accuracy: 0.4084
# Epoch 61/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5716 - accuracy: 0.4140
# Epoch 62/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5645 - accuracy: 0.4160
# Epoch 63/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5568 - accuracy: 0.4217
# Epoch 64/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5493 - accuracy: 0.4260
# Epoch 65/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5422 - accuracy: 0.4294
# Epoch 66/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5347 - accuracy: 0.4346
# Epoch 67/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5275 - accuracy: 0.4422
# Epoch 68/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5208 - accuracy: 0.4443
# Epoch 69/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5134 - accuracy: 0.4513
# Epoch 70/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.5065 - accuracy: 0.4578
# Epoch 71/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4993 - accuracy: 0.4611
# Epoch 72/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4917 - accuracy: 0.4701
# Epoch 73/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4850 - accuracy: 0.4736
# Epoch 74/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4786 - accuracy: 0.4789
# Epoch 75/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4719 - accuracy: 0.4837
# Epoch 76/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4652 - accuracy: 0.4947
# Epoch 77/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4588 - accuracy: 0.4985
# Epoch 78/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4513 - accuracy: 0.5074
# Epoch 79/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4445 - accuracy: 0.5125
# Epoch 80/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4379 - accuracy: 0.5195
# Epoch 81/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4316 - accuracy: 0.5256
# Epoch 82/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4253 - accuracy: 0.5333
# Epoch 83/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4185 - accuracy: 0.5422
# Epoch 84/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4121 - accuracy: 0.5467
# Epoch 85/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4062 - accuracy: 0.5540
# Epoch 86/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.4001 - accuracy: 0.5588
# Epoch 87/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3940 - accuracy: 0.5674
# Epoch 88/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3879 - accuracy: 0.5739
# Epoch 89/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3815 - accuracy: 0.5799
# Epoch 90/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3755 - accuracy: 0.5857
# Epoch 91/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3700 - accuracy: 0.5969
# Epoch 92/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3650 - accuracy: 0.6027
# Epoch 93/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3601 - accuracy: 0.6079
# Epoch 94/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3541 - accuracy: 0.6127
# Epoch 95/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3481 - accuracy: 0.6188
# Epoch 96/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3424 - accuracy: 0.6275
# Epoch 97/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3368 - accuracy: 0.6353
# Epoch 98/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3306 - accuracy: 0.6411
# Epoch 99/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3251 - accuracy: 0.6473
# Epoch 100/100
# 564/564 [==============================] - 5s 9ms/sample - loss: 0.3202 - accuracy: 0.6565

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=( 200 ,))
    decoder_state_input_c = tf.keras.layers.Input(shape=( 200 ,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %%
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( tokenizer.word_index[ word ] ) 
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=maxlen_questions , padding='post')

# %%
enc_model , dec_model = make_inference_models()

for _ in range(10):
    states_values = enc_model.predict( str_to_tokens( input( 'Enter question : ' ) ) )
    empty_target_seq = np.zeros( ( 1 , 1 ) )
    empty_target_seq[0, 0] = tokenizer.word_index['start']
    stop_condition = False
    decoded_translation = ''
    while not stop_condition :
        dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values )
        sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
        sampled_word = None
        for word , index in tokenizer.word_index.items() :
            if sampled_word_index == index :
                decoded_translation += ' {}'.format( word )
                sampled_word = word
        
        if sampled_word == 'end' or len(decoded_translation.split()) > maxlen_answers:
            stop_condition = True
            
        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        states_values = [ h , c ] 

    print( decoded_translation )
# Out:
# Enter question : Hi
#  hello end
# Enter question : how are you
#  i am not into a bad spouse end
# Enter question : who is your father
#  a human end
# Enter question : who is your mother
#  a human end
